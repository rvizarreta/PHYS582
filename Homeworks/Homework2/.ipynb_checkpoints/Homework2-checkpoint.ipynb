# %%
# Point to configuration files
import sys
sys.path.append('/global/cfs/projectdirs/dune/www/data/2x2/simulation/rvizarr_dev/2x2/Thesis_2x2')
# Import python packages required for analysis
from setup import *
# Import CAF Plotting libraries
import plot_manager
importlib.reload(plot_manager)
# Out:
# DUNE plot style enabled
# <module 'plot_manager' from '/global/cfs/projectdirs/dune/www/data/2x2/simulation/rvizarr_dev/2x2/Thesis_2x2/plot_manager.py'>

# %% [markdown]
# ## Quesiton 1

# %%
N_array, iterations = np.arange(0,100,5), 10000
variance_array = []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position = 0
        throws = np.random.randint(0, 2, size=int(N))
        for throw in throws:
            if throw == 0: #tails
                position -= 1
            else: #heads
                position += 1
        end_position.append(position)

    end_position = np.array(end_position)
    variance_array.append(np.var(end_position))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, np.sqrt(x_range), label=r'$\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.legend()

# %%
N_array, iterations = np.arange(0,100,5), 10000
variance_array = []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position = 0
        throws = np.random.randint(0, 2, size=int(N))
        for throw in throws:
            if throw == 0: #tails
                position -= 2
            else: #heads
                position += 1
        end_position.append(position)

    end_position = np.array(end_position)
    variance_array.append(np.var(end_position))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, (3/2)*np.sqrt(x_range), label=r'$\frac{3}{2}\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.legend()

# %%
N_array, iterations = np.arange(0,100,5), 10000
variance_array_x, variance_array_y = [], []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position_x, position_y = 0, 0
        throws = [(0, np.random.choice([-1,1])) if np.random.rand() < 0.5 else (np.random.choice([-1,1]), 0) for _ in range(N)]
        for throw_x, throw_y in throws:
            position_x += throw_x
            position_y += throw_y
        end_position.append([position_x,position_y])

    end_position = np.array(end_position)
    variance_array_x.append(np.var(end_position[:,0]))
    variance_array_y.append(np.var(end_position[:,1]))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, (1/np.sqrt(2))*np.sqrt(x_range), label=r'$\frac{1}{\sqrt{2}}\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array_x))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.title('2D Coin Flip')
plt.legend()

# %%
N_array, iterations = np.arange(0,100,5), 10000
variance_array_x, variance_array_y, variance_array_z = [], [], []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position_x, position_y, position_z = 0, 0, 0
        throws = [(0, 0, np.random.choice([-1, 1])) if np.random.rand() < 1/3 else 
            (0, np.random.choice([-1, 1]), 0) if np.random.rand() < 0.5 else 
            (np.random.choice([-1, 1]), 0, 0) 
            for _ in range(N)]
        for throw_x, throw_y, throw_z in throws:
            position_x += throw_x
            position_y += throw_y
            position_z += throw_z
        end_position.append([position_x,position_y,position_z])

    end_position = np.array(end_position)
    variance_array_x.append(np.var(end_position[:,0]))
    variance_array_y.append(np.var(end_position[:,1]))
    variance_array_z.append(np.var(end_position[:,2]))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, (1/np.sqrt(3))*np.sqrt(x_range), label=r'$\frac{1}{\sqrt{3}}\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array_x))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.title('3D Coin Flip')
plt.legend()

# %%
N_array, iterations = np.arange(0,100,5), 1000
variance_array_x, variance_array_y, variance_array_z, variance_array_q = [], [], [], []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position_x, position_y, position_z, position_q = 0, 0, 0, 0
        throws = [(0, 0, 0, np.random.choice([-1, 1])) if np.random.rand() < 1/4 else 
               (0, 0, np.random.choice([-1, 1]), 0) if np.random.rand() < 1/3 else 
               (0, np.random.choice([-1, 1]), 0, 0) if np.random.rand() < 0.5 else 
               (np.random.choice([-1, 1]), 0, 0, 0)
               for _ in range(N)]
        for throw_x, throw_y, throw_z, throw_q in throws:
            position_x += throw_x
            position_y += throw_y
            position_z += throw_z
            position_q += throw_q
        end_position.append([position_x,position_y,position_z,position_q])

    end_position = np.array(end_position)
    variance_array_x.append(np.var(end_position[:,0]))
    variance_array_y.append(np.var(end_position[:,1]))
    variance_array_z.append(np.var(end_position[:,2]))
    variance_array_q.append(np.var(end_position[:,3]))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, (1/np.sqrt(4))*np.sqrt(x_range), label=r'$\frac{1}{\sqrt{4}}\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array_x))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.title('4D Coin Flip')
plt.legend()

# %% [markdown]
# ## Question 2

# %%
# Random number generation following exponential distribution
def generate_random_dist_exp(size):
    F_inv = lambda u, b : -b*np.log(1-u)
    uniform_dist = np.random.uniform(low=0.0, high=1.0, size=size)
    x_random_values = F_inv(uniform_dist, 1)
    return x_random_values

plot_manager.display_plots(plot_funcs = {
    'Plot 1': lambda: plot_manager.make_hist(
        data=[generate_random_dist_exp(10000)], 
        bins=60, 
        range=(0, 10), 
        alpha=0.5, 
        label=[r'$\pi$'], 
        title=r'PDF', 
        xlabel='x', 
        ylabel='No. of counts',
        legend=False,
        DUNE=False
    )
})
# Out:
#     <div style="display:flex; gap:50px; justify-content:center;">
#
#         <div style="text-align:center">
#             <img src="data:image/png;base64,..." style="max-width:100%;height:auto;">
#         </div>
#
#     </div>

# %%
N_array, iterations = np.arange(1,100,5), 10000
variance_array = []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position = 0
        throws = np.random.randint(0, 2, size=int(N))
        step_sizes = generate_random_dist_exp(int(N))
        for throw, step_size in zip(throws,step_sizes):
            if throw == 0: #tails
                position -= step_size
            else: #heads
                position += step_size
        end_position.append(position)

    end_position = np.array(end_position)
    variance_array.append(np.var(end_position))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, 1.5*np.sqrt(x_range), label=r'$\frac{3}{2}\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.title('1D Mean Free Path')
plt.legend()

# %%
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, (7/5)*np.sqrt(x_range), label=r'$\frac{3}{2}\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.title('1D Mean Free Path')
plt.legend()

# %%
N_array, iterations = np.arange(0,100,5), 10000
variance_array_x, variance_array_y = [], []
position_array_x, position_array_y = [], []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position_x, position_y = 0, 0
        throws = [(0, np.random.choice([-1,1])) if np.random.rand() < 0.5 else (np.random.choice([-1,1]), 0) for _ in range(N)]
        step_sizes = generate_random_dist_exp(int(N))
        for throw_list, step_size in zip(throws, step_sizes):
            throw_x, throw_y = throw_list[0], throw_list[1]
            position_x += throw_x*step_size
            position_y += throw_y*step_size
            if N == 50 and iteration==3:
                position_array_x.append(position_x)
                position_array_y.append(position_y)
        end_position.append([position_x,position_y])

    end_position = np.array(end_position)
    variance_array_x.append(np.var(end_position[:,0]))
    variance_array_y.append(np.var(end_position[:,1]))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, np.sqrt(x_range), label=r'$\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array_x))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.title('2D Mean Free Path')
plt.legend()

# %%
N_array, iterations = np.arange(0,100,5), 10000
variance_array_x, variance_array_y, variance_array_z = [], [], []

for N in N_array:
    end_position = []
    for iteration in range(iterations):
        position_x, position_y, position_z = 0, 0, 0
        throws = [(0, 0, np.random.choice([-1, 1])) if np.random.rand() < 1/3 else 
            (0, np.random.choice([-1, 1]), 0) if np.random.rand() < 0.5 else 
            (np.random.choice([-1, 1]), 0, 0) 
            for _ in range(N)]
        step_sizes = generate_random_dist_exp(int(N))
        for throw_list, step_size in zip(throws, step_sizes):
            throw_x, throw_y, throw_z = throw_list[0], throw_list[1], throw_list[2]
            position_x += throw_x*step_size
            position_y += throw_y*step_size
            position_z += throw_z*step_size
        end_position.append([position_x,position_y,position_z])

    end_position = np.array(end_position)
    variance_array_x.append(np.var(end_position[:,0]))
    variance_array_y.append(np.var(end_position[:,1]))
    variance_array_z.append(np.var(end_position[:,2]))
    
x_range = np.linspace(0, 100, 100)
plt.plot(x_range, np.sqrt(x_range), label=r'$\sqrt{N}$', color='red', linestyle='-')
plt.scatter(N_array, np.sqrt(variance_array_x))
plt.xlabel('N')
plt.ylabel(r'$\sqrt{VAR}$')
plt.title('3D Mean Free Path')
plt.legend()

# %%
1.36/np.sqrt(2)
# Out:
# 0.9616652224137047
