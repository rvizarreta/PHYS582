# %%
from Detector import Detector
import plotly.graph_objects as go
from Particle import Particle
from GEANT5 import GEANT5
import numpy as np

# Create detector
detector = Detector()
GEANT5 = GEANT5()

# Print detector information
print(detector.get_detector_info())
# Out:
# Detector Configuration:
# Number of modules: 15
# Total length: 2984.0 mm
# Plane dimensions: 4191.0 x 4839.3 mm
# Module spacing: 20.0 mm
# Module gap: 40.0 mm
#
# Module structure:
# - X plane
# - U plane (+60°)
# - X plane
# - V plane (-60°)

# %%
test_particle = Particle(105.66, np.array([464.5213596389285, 118.61177641841195, 877.5825618903727]), 200, np.array([0, 0, -1000]))
muon_hits = GEANT5.track_muon(detector, test_particle)
# Out:
# /global/cfs/cdirs/dune/www/data/2x2/simulation/rvizarr_dev/UofR/FinalProject/GEANT5.py:26: RuntimeWarning: divide by zero encountered in scalar divide
#   dEdX = K*z**2*(avg_Z/avg_A)*(1/beta**2)*(0.5*np.log(2*ELECTRON_MASS*(beta*gamma)**2*Tmax/I_mean**2) - beta**2 - delta/2)
# /global/cfs/cdirs/dune/www/data/2x2/simulation/rvizarr_dev/UofR/FinalProject/GEANT5.py:26: RuntimeWarning: divide by zero encountered in log
#   dEdX = K*z**2*(avg_Z/avg_A)*(1/beta**2)*(0.5*np.log(2*ELECTRON_MASS*(beta*gamma)**2*Tmax/I_mean**2) - beta**2 - delta/2)

# %%
fig = detector.visualize_hits_projections(muon_hits)

# %%
muon_hits
# Out:
# [{'module': 0,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f4b5d3c0990>,
#   'intersection_point': [529.3192684211019, 135.15739893795757, 0.0],
#   'energy': 177.91768275166334,
#   'momentum_vector': array([ 65.48091092,  16.29683412, 126.24313739])},
#  {'module': 0,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f4b5d3d0790>,
#   'intersection_point': [542.2373500285728,
#    134.9515763021184,
#    45.40000000000009],
#   'energy': 151.72246068031754,
#   'momentum_vector': array([50.41487562, 14.68769134, 95.3849124 ])},
#  {'module': 0,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f4b5d3d8390>,
#   'intersection_point': [576.5329646500446,
#    167.9650723487202,
#    90.79999999999995],
#   'energy': 115.67804291798231,
#   'momentum_vector': array([21.90181858,  5.56448434, 41.31247838])},
#  {'module': 0,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f4b5d3dca90>,
# ...

# %%
GEANT5.plot_from_dict(muon_hits,'intersection_point','energy','Z (mm)', 'Energy (MeV)')

# %%
detector.strip_width
# Out:
# 33
