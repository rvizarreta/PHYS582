# %%
import numpy as np
from typing import Dict, List, Tuple
from Detector import Detector
import plotly.graph_objects as go
from Particle import Particle

# Create detector
detector = Detector()

# Print detector information
print(detector.get_detector_info())
# Out:
# Detector Configuration:
# Number of modules: 15
# Total length: 1520.0 mm
# Plane dimensions: 4191.0 x 4839.3 mm
# Module spacing: 20.0 mm
# Module gap: 40.0 mm
#
# Module structure:
# - X plane
# - U plane (+60°)
# - X plane
# - V plane (-60°)

# %%
def calculate_bethe_bloch(particle):
    ELECTRON_MASS = 0.511 # MeV
    K = 0.307075
    z = 1
    avg_Z = 0.0759*1 + 0.919*6 + 0.0051*8 + 0.0077*22
    avg_A = 0.0759*1.00784 + 0.919*12.01 + 0.0051*32 + 0.0077*47.867
    beta, gamma = particle.get_beta(), particle.get_gamma()
    I_mean = avg_Z*12 + 7
    M = particle.mass
    delta = 0
    Tmax = (2*ELECTRON_MASS*(beta*gamma)**2)/(1 + 2*ELECTRON_MASS/M*np.sqrt(1+(beta*gamma)**2) + (ELECTRON_MASS/M)**2)
    dEdX = K*z**2*(avg_Z/avg_A)*(1/beta**2)*(0.5*np.log(2*ELECTRON_MASS*(beta*gamma)**2*Tmax/I_mean**2) - beta**2 - delta/2)
    return dEdX # cm

def calculate_highland_angle(particle):
    '''
    Calculate RMS scattering angle using Highland formula
    '''
    t = 20/280 # Thickness of 20 mm and radiation length of 286 mm
    momentum = particle.momentum
    return (13.6/momentum)*np.sqrt(t)*(1 + 0.038*np.log(t))

def create_orthonormal_basis(direction):
    '''
    Create orthonormal basis given a direction vector
    '''
    p = direction / np.linalg.norm(direction) # Normalize direction
    if abs(p[2]) < 1/np.sqrt(2): # Choose most stable axis to cross with
        u = np.cross(p, [0, 0, 1]) # If not too parallel to z, cross with z
    else:
        u = np.cross(p, [1, 0, 0]) # If too parallel to z, cross with x
    u = u / np.linalg.norm(u) # Normalize u
    v = np.cross(p, u) # v completes right-handed system
    return u, v

def calculate_new_direction(particle):
    '''
    Apply multiple scattering to momentum direction
    '''
    delta_theta = calculate_highland_angle(particle)
    theta = np.random.normal(0, delta_theta)  # Polar angle
    phi = np.random.uniform(0, 2*np.pi)  # Azimuthal angle
    momentum_dir = particle.momentum/np.linalg.norm(particle.momentum)
    u, v = create_orthonormal_basis(momentum_dir) # Get orthonormal basis
    new_dir = (np.cos(theta)*momentum_dir + np.sin(theta)*(np.cos(phi)*u + np.sin(phi)*v))
    return new_dir/np.linalg.norm(new_dir)
    
def track_muon(detector, particle):
    '''
    Track muon through detector planes and record hits.
    '''
    initial_momentum = particle.momentum
    initial_energy = particle.energy
    # Starting position 1m before detector in central axis
    start_pos = particle.position  # 1m = 1000mm before z=0
    # Calculate velocity direction (assuming relativistic particle)
    velocity_dir = initial_momentum / np.linalg.norm(initial_momentum)
    # Initialize results list
    hits = []
    # Loop through all modules
    for module_idx, module in enumerate(detector.modules):
        # Check intersection with each plane in the module
        for plane_name, plane in [('X', module.x_plane1), ('U', module.u_plane), ('X', module.x_plane2), ('V', module.v_plane)]:
            # Calculate intersection point with plane
            t = (plane.position[2] - start_pos[2]) / velocity_dir[2]
            intersection = start_pos + velocity_dir * t
            # Find which strips (if any) were hit
            hit_strips = plane.find_intersecting_strips(intersection)
            # Calculate new energy
            dEdX = calculate_bethe_bloch(particle)
            new_energy = initial_energy + dEdX*2
            if new_energy > particle.mass:
                # If there was a hit, record it
                particle.energy = new_energy
                # Calculate new momentum
                velocity_dir = calculate_new_direction(particle)
                new_momentum = np.sqrt(new_energy**2 - particle.mass**2)*velocity_dir
                if hit_strips:
                    hit_info = {
                        "module": module_idx,
                        "plane_orientation": plane_name,
                        "strip": hit_strips[0],  # Take first hit if multiple
                        "intersection_point": intersection.tolist(),
                        "energy": new_energy,  
                        "momentum_vector": new_momentum
                    }
                    hits.append(hit_info)
            elif initial_energy > particle.mass and new_energy < particle.mass:
                if hit_strips:
                    particle.energy = particle.mass
                    new_momentum = 0*calculate_new_direction(particle)
                    hit_info = {
                        "module": module_idx,
                        "plane_orientation": plane_name,
                        "strip": hit_strips[0],  # Take first hit if multiple
                        "intersection_point": intersection.tolist(),
                        "energy": particle.mass,  # Muon stops in strip
                        "momentum_vector": new_momentum
                    }
                    hits.append(hit_info)
            initial_energy = new_energy
    return hits

# %%
test_particle = Particle(105.66, np.array([464.5213596389285, 118.61177641841195, 877.5825618903727]), 250, np.array([0, 0, -1000]))
muon_hits = track_muon(detector, test_particle)

# %%
fig = detector.visualize_hits_projections(muon_hits)

# %%
muon_hits
# Out:
# [{'module': 0,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3acfde10>,
#   'intersection_point': [529.3192684211019, 135.15739893795757, 0.0],
#   'energy': 248.65046943279452,
#   'momentum_vector': array([103.64924622,  27.79652258, 197.85653247])},
#  {'module': 0,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ad0dbd0>,
#   'intersection_point': [534.8616953309819,
#    143.43852691585425,
#    21.000000000000114],
#   'energy': 247.2935596095226,
#   'momentum_vector': array([103.77971457,  24.20348005, 196.55541565])},
#  {'module': 0,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad159d0>,
#   'intersection_point': [550.1678100511316, 128.31000424298057, 42.0],
#   'energy': 245.9291140460236,
#   'momentum_vector': array([102.36323583,  34.48500016, 194.03516756])},
#  {'module': 0,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ad1dfd0>,
#   'intersection_point': [560.7855579071693, 188.92222286329587, 63.0],
#   'energy': 244.55697006811064,
#   'momentum_vector': array([103.77353985,  24.13935134, 193.11245468])},
#  {'module': 1,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad26010>,
#   'intersection_point': [593.2604822441555, 138.00168364068855, 104.0],
#   'energy': 243.17695845760906,
#   'momentum_vector': array([100.68287499,  38.59650157, 190.64172228])},
#  {'module': 1,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ad2de90>,
#   'intersection_point': [594.1418961762339, 227.76265207881266, 125.0],
#   'energy': 241.78890307188448,
#   'momentum_vector': array([101.55729566,  27.39934756, 190.35028106])},
#  {'module': 1,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad35990>,
#   'intersection_point': [611.4236352599839, 164.95721533650533, 146.0],
#   'energy': 240.39262043439302,
#   'momentum_vector': array([ 98.79414054,  23.94199914, 190.5021649 ])},
#  {'module': 1,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ad3e190>,
#   'intersection_point': [605.2044713727281, 146.66664291199424, 167.0],
#   'energy': 238.9879192935115,
#   'momentum_vector': array([ 99.15928148,  30.38799721, 187.60382856])},
#  {'module': 2,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad46250>,
#   'intersection_point': [638.4966284623329, 195.67138319632855, 208.0],
#   'energy': 237.5746001465932,
#   'momentum_vector': array([ 97.58799548,  25.21330247, 187.39937981])},
#  {'module': 2,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ad4dfd0>,
#   'intersection_point': [640.0002314403412, 165.35352873133132, 229.0],
#   'energy': 236.1524547258414,
#   'momentum_vector': array([ 96.89162542,  37.81779433, 183.80906841])},
#  {'module': 2,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad55a50>,
#   'intersection_point': [658.9148882934735, 257.18123335045846, 250.0],
#   'energy': 234.72126544219174,
#   'momentum_vector': array([ 97.47393291,  23.24190862, 184.08879091])},
#  {'module': 2,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ad5e2d0>,
#   'intersection_point': [672.9870304513997, 160.46857450859002, 271.0],
#   'energy': 233.28080478293694,
#   'momentum_vector': array([ 95.84207327,  23.80348584, 183.03985723])},
#  {'module': 3,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad66510>,
#   'intersection_point': [686.980431680845, 170.61952461275874, 312.0],
#   'energy': 231.83083465830674,
#   'momentum_vector': array([ 96.12764906,  22.0515865 , 181.25866301])},
#  {'module': 3,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ad6e210>,
#   'intersection_point': [706.9353490438334, 162.17026161777014, 333.0],
#   'energy': 230.37110569161922,
#   'momentum_vector': array([ 95.91283153,  24.2827833 , 179.21463646])},
#  {'module': 3,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad75d90>,
#   'intersection_point': [724.6393289088066, 183.4609562930084, 354.0],
#   'energy': 228.90135644693666,
#   'momentum_vector': array([ 94.43363371,  29.01938049, 177.40338149])},
#  {'module': 3,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ad7e590>,
#   'intersection_point': [731.9265577456731, 224.9204487429884, 375.0],
#   'energy': 227.42131258737345,
#   'momentum_vector': array([ 93.01080685,  23.08367243, 177.12298466])},
#  {'module': 4,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad86650>,
#   'intersection_point': [743.5698012342518, 184.54115496366026, 416.0],
#   'energy': 225.9306859562986,
#   'momentum_vector': array([ 91.6888917 ,  30.90869242, 174.69527506])},
#  {'module': 4,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ad8e3d0>,
#   'intersection_point': [754.2100799807586, 254.24723702208294, 437.0],
#   'energy': 224.42917357262996,
#   'momentum_vector': array([ 91.70338515,  24.53143679, 173.76166468])},
#  {'module': 4,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ad95f50>,
#   'intersection_point': [769.4650934466406, 205.83846793364415, 458.0],
#   'energy': 222.91645653020595,
#   'momentum_vector': array([ 91.13189554,  22.77959283, 172.34784234])},
#  {'module': 4,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ad9e850>,
#   'intersection_point': [782.046770515938, 195.4826781327946, 479.0],
#   'energy': 221.39219878981208,
#   'momentum_vector': array([ 90.33660157,  23.68688808, 170.67132107])},
#  {'module': 5,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ada68d0>,
#   'intersection_point': [804.5384164780311, 210.95559379646792, 520.0],
#   'energy': 219.85604585079992,
#   'momentum_vector': array([ 88.46309344,  25.05652538, 169.4670969 ])},
#  {'module': 5,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3adae5d0>,
#   'intersection_point': [804.4135379730176, 227.84426193154457, 541.0],
#   'energy': 218.30762328731626,
#   'momentum_vector': array([ 89.90490068,  22.92352036, 166.99043036])},
#  {'module': 5,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3adb6050>,
#   'intersection_point': [840.9551048129842, 214.42269910258085, 562.0],
#   'energy': 216.7465351319102,
#   'momentum_vector': array([ 86.10527243,  23.69459754, 166.85164967])},
#  {'module': 5,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3adbead0>,
#   'intersection_point': [816.9211783477818, 224.80178034324064, 583.0],
#   'energy': 215.17236208663525,
#   'momentum_vector': array([ 88.1474497 ,  18.54798455, 164.38098791])},
#  {'module': 6,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3adc6b90>,
#   'intersection_point': [870.8516728357805, 183.24459109206254, 624.0],
#   'energy': 213.584659538633,
#   'momentum_vector': array([ 85.52164902,  16.20781118, 163.94427589])},
#  {'module': 6,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3adce710>,
#   'intersection_point': [858.115429045459, 162.62751018745007, 645.0],
#   'energy': 211.98295535347188,
#   'momentum_vector': array([ 85.20250297,  26.46276193, 160.66422588])},
#  {'module': 6,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3add6190>,
#   'intersection_point': [883.5032763159928, 274.40434318213977, 666.0],
#   'energy': 210.36674741509293,
#   'momentum_vector': array([ 84.91683842,  20.26187914, 159.58922151])},
#  {'module': 6,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3addec10>,
#   'intersection_point': [897.646501829722, 214.1860821198642, 687.0],
#   'energy': 208.73550087592903,
#   'momentum_vector': array([ 82.61969778,  25.89263355, 157.82911896])},
#  {'module': 7,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ade6c50>,
#   'intersection_point': [904.5658919198369, 283.48679294255436, 728.0],
#   'energy': 207.08864507441672,
#   'momentum_vector': array([ 83.23089037,  16.08212719, 156.63861399])},
#  {'module': 7,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3abf2990>,
#   'intersection_point': [929.3419007536437, 179.57028435927407, 749.0],
#   'energy': 205.42557006946367,
#   'momentum_vector': array([ 81.81095204,  22.23207044, 154.429053  ])},
#  {'module': 7,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3abfa410>,
#   'intersection_point': [937.6822708886276, 254.8145177802151, 770.0],
#   'energy': 203.74562273215486,
#   'momentum_vector': array([ 80.79055419,  20.36340583, 152.99170317])},
#  {'module': 7,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ac02e90>,
#   'intersection_point': [945.7760097384449, 238.3845600287682, 791.0],
#   'energy': 202.04810232367618,
#   'momentum_vector': array([ 80.46657451,  19.92490985, 150.95538548])},
#  {'module': 8,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac0af50>,
#   'intersection_point': [976.5452490412908, 241.80942425238229, 832.0],
#   'energy': 200.33225547459176,
#   'momentum_vector': array([ 79.57891636,  18.96417767, 149.25325129])},
#  {'module': 8,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ac12ad0>,
#   'intersection_point': [987.9833822152212, 235.4429195080885, 853.0],
#   'energy': 198.59727046356173,
#   'momentum_vector': array([ 78.33404145,  23.47146367, 146.93436827])},
#  {'module': 8,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac1a550>,
#   'intersection_point': [999.0718672201098, 299.35489856233005, 874.0],
#   'energy': 196.84227067246943,
#   'momentum_vector': array([ 76.0276198 ,  19.96443048, 146.30128662])},
#  {'module': 8,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ac230d0>,
#   'intersection_point': [984.7646787992401,
#    258.5937323780364,
#    894.9999999999998],
#   'energy': 195.0663070685992,
#   'momentum_vector': array([ 76.36182752,  16.09663513, 144.21025688])},
#  {'module': 9,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac2b150>,
#   'intersection_point': [1025.145515111617,
#    216.0947930394104,
#    936.0000000000002],
#   'energy': 193.26834953147008,
#   'momentum_vector': array([ 75.5890235 ,  19.24202059, 141.79091473])},
#  {'module': 9,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ac32d50>,
#   'intersection_point': [1043.2806592507884, 265.57861181527903, 957.0],
#   'energy': 191.44727680017985,
#   'momentum_vector': array([ 74.38698408,  17.92928858, 140.11831217])},
#  {'module': 9,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac3a650>,
#   'intersection_point': [1050.094396883981, 253.10134176137987, 978.0],
#   'energy': 189.6018647639558,
#   'momentum_vector': array([ 72.94692193,  20.55611998, 137.98921709])},
#  {'module': 9,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ac431d0>,
#   'intersection_point': [1056.7557379797674, 297.7890932288385, 999.0],
#   'energy': 187.73077275038,
#   'momentum_vector': array([ 71.66329087,  18.43531919, 136.39398515])},
#  {'module': 10,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac4b350>,
#   'intersection_point': [1071.8442841209664,
#    275.73100898840255,
#    1039.9999999999998],
#   'energy': 185.8325273774357,
#   'momentum_vector': array([ 70.7041235 ,  18.75159365, 134.23485869])},
#  {'module': 10,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ac52f50>,
#   'intersection_point': [1085.5689792396947, 287.90609895415406, 1061.0],
#   'energy': 183.90550342014052,
#   'momentum_vector': array([ 69.6899296 ,  19.49619725, 131.98640306])},
#  {'module': 10,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac5a7d0>,
#   'intersection_point': [1099.3134904362832, 307.5398809039145, 1082.0],
#   'energy': 181.94790099030956,
#   'momentum_vector': array([ 69.35442357,  12.72034211, 130.26572804])},
#  {'module': 10,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ac63450>,
#   'intersection_point': [1119.6525360234284, 205.35623494817946, 1103.0],
#   'energy': 179.95771812503253,
#   'momentum_vector': array([ 67.99426779,  15.1534936 , 127.93707786])},
#  {'module': 11,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac6b510>,
#   'intersection_point': [1139.4641224409168, 253.9458522626946, 1144.0],
#   'energy': 177.93271760573447,
#   'momentum_vector': array([ 66.46855153,  16.86134418, 125.67276206])},
#  {'module': 11,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ac73190>,
#   'intersection_point': [1145.0724222984866, 290.4751161656422, 1165.0],
#   'energy': 175.87038645595865,
#   'momentum_vector': array([ 66.03712606,  16.29445466, 123.04448773])},
#  {'module': 11,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac7ea10>,
#   'intersection_point': [1173.2110900379616, 289.48617328342567, 1186.0],
#   'energy': 173.76788604882015,
#   'momentum_vector': array([ 64.58328868,  12.41335504, 121.2689163 ])},
#  {'module': 11,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ac83710>,
#   'intersection_point': [1175.365645744958, 225.91341129290242, 1207.0],
#   'energy': 171.62199002879598,
#   'momentum_vector': array([ 62.26873251,  17.01920463, 118.8403277 ])},
#  {'module': 12,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac8b750>,
#   'intersection_point': [1177.8839169641103, 321.93761786306504, 1248.0],
#   'energy': 169.4290062161221,
#   'momentum_vector': array([ 61.70839537,  11.30932914, 116.64615537])},
#  {'module': 12,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3ac93150>,
#   'intersection_point': [1200.3511702756468, 219.9889720261087, 1269.0],
#   'energy': 167.18467715682527,
#   'momentum_vector': array([ 59.8808531 ,  15.54527477, 113.8389588 ])},
#  {'module': 12,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3ac9ea50>,
#   'intersection_point': [1204.5713967931376, 312.710864624235, 1290.0],
#   'energy': 164.8840517522011,
#   'momentum_vector': array([ 59.09341161,   9.86487316, 111.50501291])},
#  {'module': 12,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3aca3910>,
#   'intersection_point': [1224.7420152242469, 204.45468134560895, 1311.0],
#   'energy': 162.52131702786562,
#   'momentum_vector': array([ 57.28116051,  13.40734279, 108.57372932])},
#  {'module': 13,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3acab9d0>,
#   'intersection_point': [1240.8645292255474, 290.43922906409983, 1352.0],
#   'energy': 160.0895738716746,
#   'momentum_vector': array([ 55.80387008,  16.10046184, 105.31542753])},
#  {'module': 13,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3acb3550>,
#   'intersection_point': [1257.3901735771597, 362.78061865769314, 1373.0],
#   'energy': 157.58053223546713,
#   'momentum_vector': array([ 55.04783523,  14.48698293, 102.11489461])},
#  {'module': 13,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3acbec50>,
#   'intersection_point': [1290.5513739350697, 339.6354397037837, 1394.0],
#   'energy': 154.98408759958997,
#   'momentum_vector': array([52.78710713, 11.65593873, 99.66790969])},
#  {'module': 13,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3acc3a50>,
#   'intersection_point': [1279.0562590750217, 282.4288392392863, 1415.0],
#   'energy': 152.28771718194,
#   'momentum_vector': array([50.46007634, 14.91776769, 96.22241998])},
#  {'module': 14,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3accbc10>,
#   'intersection_point': [1287.9529272754762, 380.7640407917726, 1456.0],
#   'energy': 149.47559301902425,
#   'momentum_vector': array([49.16747683, 12.77508725, 92.72687677])},
#  {'module': 14,
#   'plane_orientation': 'U',
#   'strip': <Strip.Strip at 0x7f2e3acd3710>,
#   'intersection_point': [1313.4038839638747, 341.2591065511664, 1477.0],
#   'energy': 146.52723210696223,
#   'momentum_vector': array([47.96982579, 12.1372458 , 88.6441043 ])},
#  {'module': 14,
#   'plane_orientation': 'X',
#   'strip': <Strip.Strip at 0x7f2e3acdee90>,
#   'intersection_point': [1351.7946374698, 342.02883818360993, 1498.0],
#   'energy': 143.41535227240425,
#   'momentum_vector': array([44.64995494, 13.26890096, 85.05436766])},
#  {'module': 14,
#   'plane_orientation': 'V',
#   'strip': <Strip.Strip at 0x7f2e3ace3c90>,
#   'intersection_point': [1322.3687339249977, 392.9764272195099, 1519.0],
#   'energy': 140.1022828351603,
#   'momentum_vector': array([42.58830325, 11.01543149, 80.80538813])}]
